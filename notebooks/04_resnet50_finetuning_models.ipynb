# %%
import pandas as pd

# %%
from io import StringIO

# %%
d = {
'resnet50 top 2000 v1 batch 250 adam_lr 0.001': 
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.44348075459,0.536811915495,2.37048462624,0.554800475531
1,2.216977728,0.572301213888,2.3866510376,0.561754249327
2,2.17184289751,0.58105719963,2.40218271948,0.565267605785''',
'resnet50 top 2000 v2 dense 4096 dense 4096 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.06086262536,0.565758715833,1.83288306556,0.602869039866
1,1.62823607951,0.635337153614,1.73761082865,0.625091939589
2,1.4630174207,0.664009738766,1.70849434036,0.636215543414
3,1.35523842331,0.683030371677,1.69014021563,0.642585783245''',
'resnet50 top 2000 v3 dense 4096 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.12350102994,0.558409334233,1.94925555729,0.586365986081
1,1.78010955204,0.613317047761,1.85464378124,0.603890223421
2,1.67043692167,0.631762343428,1.81743656326,0.612090082921
3,1.60499768006,0.642930881811,1.8023617186,0.616557761814''',
'resnet50 top 2000 v4 dense 2048 dense 2048 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.04063779467,0.568145318741,1.83716592345,0.601683738213
1,1.64584632194,0.632411176714,1.73621394587,0.62332310286
2,1.50662050509,0.656539228806,1.71557153511,0.630520014816
3,1.42078364487,0.671579084355,1.70915894838,0.635224753747''',
'resnet50 top 2000 v5 dense 1024 dense 1024 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.09750492641,0.558150793608,1.91130708855,0.589411300828
1,1.75000241622,0.614920452695,1.82413709117,0.606978088482
2,1.63740433565,0.634348185315,1.77750531961,0.617548552231
3,1.57051693939,0.646111306407,1.76112189075,0.622848981982''',
'resnet50 top 2000 v6 dense 6144 dense 6144 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.09667323445,0.561318242961,1.86376021076,0.598474303354
1,1.64801593228,0.631650793842,1.75059573166,0.623244083118
2,1.48300267809,0.660243439689,1.7085827317,0.633826704627
3,1.37384978609,0.679435184936,1.73201241942,0.636288485963''',
'resnet50 top 2000 v2 -> v7 dense 4096 dense 4096 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.10591642572,0.731807475779,1.65458269179,0.663483572063
1,1.04890828143,0.743744757315,1.65304053002,0.665191624819''',
'resnet50 full v1 dense 4096 dense 4096 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.33686291869,0.540140666142,2.11201902367,0.5761058622
1,1.86149831886,0.608883190501,2.01582864002,0.599006843324
2,1.6828341136,0.636923865277,1.99463773255,0.608091719734
3,1.56716919703,0.655337840666,2.00614002227,0.610488799987''',
'resnet50 full v1 -> v2 dense 4096 dense 4096 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.28520605936,0.705231427636,1.93365053419,0.635592347761
1,1.22037411259,0.717417960077,1.93466018107,0.637463101137''',
'resnet50 top 3000 v1 dense 4096 dense 4096 batch 250 adam_lr 0.001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,2.20647050405,0.550729498823,1.98092553972,0.587563801865
1,1.75111747723,0.620434236847,1.86491538244,0.611513827386
2,1.5776891967,0.649134547875,1.84409055159,0.620989529637
3,1.46479061492,0.668166379742,1.84775283528,0.62670893742''',
'resnet50 top 3000 v1 -> v2 dense 4096 dense 4096 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.19738724084,0.71787025406,1.79871251386,0.649158790308
1,1.13702748868,0.729877640648,1.79551665699,0.651754794041''',
'resnet50 top 2000 v3 -> v8 dense 4096 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.44376897598,0.67379004633,1.72040410768,0.637382611603''',
'resnet50 top 2000 v4 -> v9 dense 2048 dense 2048 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.21559651616,0.71154908621,1.64952405013,0.655666656135''',
'resnet50 top 2000 v5 -> v10 dense 1024 dense 1024 batch 500 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.40667108493,0.677224744303,1.69316584331,0.642020484205''',
'resnet50 top 2000 v6 -> v11 dense 6144 dense 6144 batch 250 adam_lr 0.0001':
'''epoch,loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
0,1.12038098922,0.729128632479,1.66561637101,0.66206120992''',
}

# %%
dfs = []

for k, v in d.items():
    df = pd.read_csv(StringIO(v))
    df.index = pd.MultiIndex.from_tuples([(k, x) for x in df['epoch']])
    dfs.append(df.drop('epoch', axis=1))
    
all_df = pd.concat(dfs)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(all_df)
# Out:
#                                                           loss  \
# resnet50 top 2000 v1 batch 250 adam_lr 0.001       0  2.443481
#                                                    1  2.216978
#                                                    2  2.171843
# resnet50 top 2000 v2 dense 4096 dense 4096 batc... 0  2.060863
#                                                    1  1.628236
#                                                    2  1.463017
#                                                    3  1.355238
# resnet50 top 2000 v3 dense 4096 batch 250 adam_... 0  2.123501
#                                                    1  1.780110
#                                                    2  1.670437
#                                                    3  1.604998
# resnet50 top 2000 v4 dense 2048 dense 2048 batc... 0  2.040638
#                                                    1  1.645846
#                                                    2  1.506621
# ...
